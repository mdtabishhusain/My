# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.

# %% [markdown]
# A T-test is a parametric test applied to identify how the average of two data sets differs when population standard deviation is not given. When the sample size is small, and the population standard deviation is unknown, the T-test is used in conjunction with the t-distribution. T test uses sample standard deviation when population standard deviation is absent whereas z score uses population standard deviation.
#
# Z test is used to find the area under the curve. It uses the z score and z table. Also there is a need for the p value in z test. We will see few examples to understand z test better.
# Note that in a problem statement, if standard deviation of population data is given and the size of the sample n≥30, then z test is used to solve the problem

# %% [markdown]
# Q2: Differentiate between one-tailed and two-tailed tests.

# %% [markdown]
# The One-Tailed test, also called a directional test, considers a critical region of data that would result in the null hypothesis being rejected if the test sample falls into it, inevitably meaning the acceptance of the alternate hypothesis.
# In a one-tailed test, the critical distribution area is one-sided, meaning the test sample is either greater or lesser than a specific value.
#
# In two tails, the test sample is checked to be greater or less than a range of values in a Two-Tailed test, implying that the critical distribution area is two-sided.
# If the sample falls within this range, the alternate hypothesis will be accepted, and the null hypothesis will be rejected.

# %% [markdown]
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.

# %% [markdown]
# A Type-I error occurs when sample results reject the null hypothesis despite being true.
#
# Example - Suppose a teacher evaluates the examination paper to decide whether a student passes or fails.
#
# H_0: Student has passed
#
# H_1: Student has failed
#
# Type I error will be the teacher failing the student [rejects H_0] although the student scored the passing marks [H_0 was true]
#
#
# A Type-II error occurs when the null hypothesis is not rejected when it is false, unlike a Type-I error.
#
# Example - Suppose a teacher evaluates the examination paper to decide whether a student passes or fails.
#
# H_0: Student has passed
#
# H_1: Student has failed Type II error will be the case where the teacher passes the student [do not reject H_0] although the student did not score the passing marks [H_1 is true].

# %% [markdown]
# Q4: Explain Bayes's theorem with an example.

# %% [markdown]
# Bayes’ theorem describes the probability of occurrence of an event related to any condition. It is also considered for the case of conditional probability.
# The probability of occurrence of any event A when another event B in relation to A has already occurred is known as conditional probability. It is depicted by P(A|B).

# %% [markdown]
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.

# %% [markdown]
# Confidence interval in a given sample is an interval which consists of lower bound and upper bound with k% of confidence level
# 	It is given as sum/subtract of point estimation and margin of error
# 	Confidence Interval = Point Estimation ± Margin of Error
# 	Mathematically,
#    C.I=x ̅±z_(α⁄2)  .σ/√n
# Where,
# α is the p value
# z is the z score
# x ̅ is point of estimation
#
# For lower bound,
#    C.I=x ̅-z_(α⁄2)  .σ/√n
# 	For upper bound.
#    C.I=x ̅+z_(α⁄2)  .σ/√n
# 	Example – Calculate the 95% interval for a sample mean of 40 and population standard deviation of 40 with sample size equal to 100.
# 	Solution – Given,
# Sample mean x ̅=40
# Population standard deviation σ=40
# Sample size n=100
# p value α=1-0.95
# α=0.05
#  z_(α⁄2)=z_(0.05⁄2)
#  z_(α⁄2)=z_0.025
# For locating
#  z_0.025= 1-0.025
#  z_0.025= 0.975
#  z_0.025= 1.96
#
#  We know,
# 		Confidence Interval = point estimation ± margin of error
# 		i.e. C.I=x ̅±z_(α⁄2)  .σ/√n
# 		       For lower bound,
# 				C.I=x ̅-z_(α⁄2)  .σ/√n
# 			      → C.I=40-1.96 × 40/√100
# 			      → C.I=32.16
# 		       For upper bound,
# 				C.I=x ̅+z_(α⁄2)  .σ/√n
# 			      → C.I=40-1.96 ×  40/√100
# 			      → C.I=47.84

# %% [markdown]
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.

# %% [markdown]
# Suppose we have a medical test for a rare disease, and the test is known to be 95% accurate. The probability of a person having the disease is 1%. What is the probability that a person who tests positive actually has the disease?
#
# Probability of having the disease (prior probability): 1%
# Probability of testing positive given having the disease (sensitivity): 95%
# Probability of testing negative given not having the disease (specificity): 95%
# Probability of not having the disease (complementary of having the disease): 99%
# We want to calculate the probability of having the disease given testing positive.
#
# Using Bayes' Theorem:
#
# Calculate the total probability of testing positive (
# �
# (
# Testing Positive
# )
# P(Testing Positive)):
# �
# (
# Testing Positive
# )
# =
# (
# Sensitivity
# )
# ×
# (
# Probability of having the disease
# )
# +
# (
# False Positive Rate
# )
# ×
# (
# Probability of not having the disease
# )
# P(Testing Positive)=(Sensitivity)×(Probability of having the disease)+(False Positive Rate)×(Probability of not having the disease)
#
# Calculate the probability of having the disease given testing positive using Bayes' Theorem:
# �
# (
# Having the Disease
# ∣
# Testing Positive
# )
# =
# Sensitivity
# ×
# Probability of having the disease
# Total Probability of Testing Positive
# P(Having the Disease∣Testing Positive)=
# Total Probability of Testing Positive
# Sensitivity×Probability of having the disease
#
#
# Now, plug the values into the formulas to calculate the probabilities step by step.

# %% [markdown]
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.

# %% [markdown]
# To calculate the 95% confidence interval for a sample mean, we typically use the formula:
#
# Confidence Interval
# =
# Mean
# ±
# (
# Z-value
# ×
# Standard Deviation
# Sample Size
# )
# Confidence Interval=Mean±(Z-value×
# Sample Size
# ​
#
# Standard Deviation
# ​
#  )
#
# Where:
#
# Mean is the sample mean (given as 50 in this case).
# Z-value corresponds to the z-score for the desired confidence level (95% in this case).
# Standard Deviation is the sample standard deviation (given as 5 in this case).
# Sample Size is the number of observations in the sample.
# The Z-value for a 95% confidence interval is approximately 1.96 (for a standard normal distribution).
#
# Let's plug the values into the formula and calculate the confidence interval:
#
# Confidence Interval
# =
# 50
# ±
# (
# 1.96
# ×
# 5
# �
# )
# Confidence Interval=50±(1.96×
# n
# ​
#
# 5
# ​
#  )
#
# Since we're calculating a confidence interval, we don't know the sample size (n) from the given information. However, if you have a specific sample size, you can substitute that value into the formula to get a precise confidence interval.
#
# Now, let's interpret the results:
#
# The 95% confidence interval for the sample mean of 50 with a standard deviation of 5 would be the range within which we are 95% confident that the true population mean lies. For example, if we repeat this sampling and confidence interval calculation process many times, about 95% of those intervals will contain the true population mean.
#
# In this case, the interval will be centered around the sample mean of 50, and the width of the interval (how spread out it is) is determined by the standard deviation and the sample size. The larger the sample size, the narrower the interval, indicating greater precision in our estimate of the population mean.

# %% [markdown]
# Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
# Provide an example of a scenario where a larger sample size would result in a smaller margin of error.

# %% [markdown]
# The margin of error in a confidence interval is a measure of the uncertainty or variability in our estimate of a population parameter (e.g., mean or proportion) based on a sample. It quantifies how much the estimate from the sample could vary from the true population parameter. A smaller margin of error indicates greater precision and confidence in our estimate.
#
# The formula for calculating the margin of error in a confidence interval is:
#
# Margin of Error =
# Z-value
# ×
# (
# Standard Deviation
# Sample Size
# )
# Margin of Error=Z-value×(
# Sample Size
# ​
#
# Standard Deviation
# ​
#  )
#
# Where:
#
# Z-value corresponds to the z-score for the desired confidence level.
# Standard Deviation is the sample standard deviation (or population standard deviation, if known).
# Sample Size is the number of observations in the sample.
# Now, let's discuss how sample size affects the margin of error:
#
# Inverse Relationship with Sample Size:
#
# The margin of error is inversely proportional to the square root of the sample size. As the sample size increases, the square root of the sample size increases, resulting in a smaller denominator in the formula, thus reducing the margin of error.
# Larger sample sizes lead to more precise estimates because they provide more information about the population, allowing for a more accurate estimation of the true parameter.
# Effect on Confidence Interval Width:
#
# A larger sample size results in a narrower confidence interval, as the margin of error decreases due to the inverse relationship with the square root of the sample size.
# Conversely, a smaller sample size leads to a wider confidence interval, indicating greater uncertainty and a larger margin of error.
# Example Scenario:
# Let's consider an example comparing the margin of error for two different sample sizes, assuming the same standard deviation and desired confidence level.
#
# Sample Size 1: 1000
# Sample Size 2: 5000
# Standard Deviation: 10 (hypothetical value)
# Z-value for a 95% confidence interval: approximately 1.96 (standard for a normal distribution)
# Using the formula for the margin of error:
#
# For Sample Size 1:
# Margin of Error
# 1
# =
# 1.96
# ×
# (
# 10
# 1000
# )
# Margin of Error
# 1
# ​
#  =1.96×(
# 1000
# ​
#
# 10
# ​
#  )
#
# For Sample Size 2:
# Margin of Error
# 2
# =
# 1.96
# ×
# (
# 10
# 5000
# )
# Margin of Error
# 2
# ​
#  =1.96×(
# 5000
# ​
#
# 10
# ​
#  )
#
# Calculate the margin of error for both sample sizes to observe the effect of the larger sample size on the margin of error.

# %% [markdown]
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.

# %% [markdown]
# The z-score (or standard score) measures how many standard deviations a particular data point is from the mean of a population. It's calculated using the formula:
#
# Z-score =
# X
# −
# Population Mean
# Population Standard Deviation
# Z-score=
# Population Standard Deviation
# X−Population Mean
# ​
#
#
# Given the values in the question:
#
# X
# X (data point value) = 75
# Population Mean = 70
# Population Standard Deviation = 5
# Plug these values into the formula to calculate the z-score:
#
# Z-score =
# 75
# −
# 70/
# 5 =
# 1
# Z-score=
# 5
# 75−70
# ​
#  =1

# %% [markdown]
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.

# %% [markdown]
# To determine if the new weight loss drug is significantly effective at a 95% confidence level using a t-test, we need to set up and conduct a hypothesis test. Here are the steps involved:
#
# Step 1: Formulate Hypotheses
#
# Null Hypothesis (
# �
# 0
# H
# 0
# ​
#  ): The new weight loss drug is not significantly effective; the population mean weight loss (
# �
# μ) is equal to or less than 0 pounds.
# �
# 0
# :
# �
# ≤
# 0
# H
# 0
# ​
#  :μ≤0
# Alternative Hypothesis (
# �
# 1
# H
# 1
# ​
#  ): The new weight loss drug is significantly effective; the population mean weight loss (
# �
# μ) is greater than 0 pounds.
# �
# 1
# :
# �
# >
# 0
# H
# 1
# ​
#  :μ>0
# Step 2: Choose the Significance Level
# We are given a 95% confidence level, which corresponds to a significance level (
# �
# α) of 0.05. This means we'll reject the null hypothesis if the p-value is less than 0.05.
#
# Step 3: Collect and Summarize Data
# From the information provided:
#
# Sample Size (
# �
# n): 50
# Sample Mean (
# �
# ˉ
# x
# ˉ
#  ): 6 pounds
# Sample Standard Deviation (
# �
# s): 2.5 pounds
# Step 4: Conduct the t-test
# We will perform a one-sample t-test because we are comparing the sample mean to a known value (0 pounds). The formula for the t-statistic is:
#
# �
# =
# �
# ˉ
# −
# �
# �
# �
# t=
# n
# ​
#
# s
# ​
#
# x
# ˉ
#  −μ
# ​
#
#
# where
# �
# ˉ
# x
# ˉ
#   is the sample mean,
# �
# μ is the population mean under the null hypothesis,
# �
# s is the sample standard deviation, and
# �
# n is the sample size.
#
# Substitute the values into the formula:
#
# �
# =
# 6
# −
# 0
# 2.5
# 50
# t=
# 50
# ​
#
# 2.5
# ​
#
# 6−0
# ​
#
#
# Calculate
# �
# t:
#
# �
# ≈
# 6
# 2.5
# /
# 50
# ≈
# 6
# 2.5
# /
# 7.07
# ≈
# 6
# 0.354
# ≈
# 16.95
# t≈
# 2.5/
# 50
# ​
#
# 6
# ​
#  ≈
# 2.5/7.07
# 6
# ​
#  ≈
# 0.354
# 6
# ​
#  ≈16.95
#
# Step 5: Determine the p-value
# Using the t-distribution table or a calculator, find the p-value corresponding to a t-statistic of 16.95 with 49 degrees of freedom. The p-value will be very close to 0.
#
# Step 6: Make a Decision
# Since the p-value is much less than the significance level (
# �
# α), we reject the null hypothesis (
# �
# 0
# H
# 0
# ​
#  ).
#
# Step 7: Conclusion
# Based on the results of the hypothesis test, there is strong evidence to suggest that the new weight loss drug is significantly effective at a 95% confidence level. Participants in the study lost an average of 6 pounds, which is significantly greater than zero.

# %% [markdown]
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
# confidence interval for the true proportion of people who are satisfied with their job.

# %% [markdown]
# To calculate the 95% confidence interval for the true proportion of people who are satisfied with their job, we'll use the formula for a confidence interval for a proportion:
#
# Confidence Interval=
# �
# ^
# ±
# �
# ×
# �
# ^
# (
# 1
# −
# �
# ^
# )
# �
# Confidence Interval=
# p
# ^
# ​
#  ±Z×
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
#
# Where:
#
# �
# ^
# p
# ^
# ​
#   is the sample proportion (65% or 0.65 in decimal form),
# �
# Z is the Z-value corresponding to the desired confidence level (for 95% confidence, it's approximately 1.96 for a large enough sample size),
# �
# n is the sample size (500 in this case).
# Let's plug the values into the formula and calculate the confidence interval:
#
# Sample Proportion (
# �
# ^
# )
# =
# 0.65
# Sample Proportion (
# p
# ^
# ​
#  )=0.65
# \text{Z-value (for 95% confidence)} = 1.96
# Sample Size (
# �
# )
# =
# 500
# Sample Size (n)=500
#
# Confidence Interval=
# 0.65
# ±
# 1.96
# ×
# 0.65
# ×
# (
# 1
# −
# 0.65
# )
# 500
# Confidence Interval=0.65±1.96×
# 500
# 0.65×(1−0.65)
# ​
#
# ​
#
#
# Now, calculate the margin of error:
#
# Margin of Error=
# 1.96
# ×
# 0.65
# ×
# (
# 1
# −
# 0.65
# )
# 500
# Margin of Error=1.96×
# 500
# 0.65×(1−0.65)
# ​
#
# ​
#
#
# Finally, calculate the lower and upper bounds of the confidence interval:
#
# Lower Bound=
# �
# ^
# −
# Margin of Error
# Lower Bound=
# p
# ^
# ​
#  −Margin of Error
# Upper Bound=
# �
# ^
# +
# Margin of Error
# Upper Bound=
# p
# ^
# ​
#  +Margin of Error
#
# Plug the values into the formulas to calculate the confidence interval.
#
# Let's go ahead and calculate the 95% confidence interval for the true proportion of people who are satisfied with their job.
#
# Margin of Error=
# 1.96
# ×
# 0.65
# ×
# (
# 1
# −
# 0.65
# )
# 500
# Margin of Error=1.96×
# 500
# 0.65×(1−0.65)
# ​
#
# ​
#
#
# Margin of Error
# ≈
# 1.96
# ×
# 0.65
# ×
# 0.35
# 500
# Margin of Error≈1.96×
# 500
# 0.65×0.35
# ​
#
# ​
#
# Margin of Error
# ≈
# 1.96
# ×
# 0.2275
# 500
# Margin of Error≈1.96×
# 500
# 0.2275
# ​
#
# ​
#
# Margin of Error
# ≈
# 1.96
# ×
# 0.02129
# Margin of Error≈1.96×0.02129
# Margin of Error
# ≈
# 0.0417
# Margin of Error≈0.0417
#
# Now, calculate the lower and upper bounds of the confidence interval:
#
# Lower Bound=
# 0.65
# −
# 0.0417
# Lower Bound=0.65−0.0417
# Lower Bound
# ≈
# 0.6083
# Lower Bound≈0.6083
#
# Upper Bound=
# 0.65
# +
# 0.0417
# Upper Bound=0.65+0.0417
# Upper Bound
# ≈
# 0.6917
# Upper Bound≈0.6917
#
# Therefore, the 95% confidence interval for the true proportion of people who are satisfied with their job is approximately
# (
# 0.6083
# ,
# 0.6917
# )
# (0.6083,0.6917). This means we can be 95% confident that the true proportion of people satisfied with their job falls within this range.

# %% [markdown]
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
# Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.

# %% [markdown]
# To determine if there is a significant difference in student performance between the two teaching methods, we'll conduct a two-sample t-test. Here are the steps involved:
#
# Step 1: Formulate Hypotheses
#
# Null Hypothesis (
# �
# 0
# H
# 0
# ​
#  ): There is no significant difference in student performance between the two teaching methods; the population means are equal.
# �
# 0
# :
# �
# �
# −
# �
# �
# =
# 0
# H
# 0
# ​
#  :μ
# A
# ​
#  −μ
# B
# ​
#  =0
# Alternative Hypothesis (
# �
# 1
# H
# 1
# ​
#  ): There is a significant difference in student performance between the two teaching methods; the population means are not equal.
# �
# 1
# :
# �
# �
# −
# �
# �
# ≠
# 0
# H
# 1
# ​
#  :μ
# A
# ​
#  −μ
# B
# ​
#
# 
# =0 (two-tailed test)
# Step 2: Choose the Significance Level
# We are given a significance level (
# �
# α) of 0.01. This is the probability of rejecting the null hypothesis when it is true (Type I error), so we want to minimize this probability.
#
# Step 3: Collect and Summarize Data
# For Sample A:
#
# Sample Mean (
# �
# ˉ
# �
# x
# ˉ
#
# A
# ​
#  ): 85
# Sample Standard Deviation (
# �
# �
# s
# A
# ​
#  ): 6
# For Sample B:
#
# Sample Mean (
# �
# ˉ
# �
# x
# ˉ
#
# B
# ​
#  ): 82
# Sample Standard Deviation (
# �
# �
# s
# B
# ​
#  ): 5
# Sample sizes are not provided, so we'll assume they are reasonably large for the t-test to be valid.
#
# Step 4: Conduct the t-test
# We'll use the formula for the two-sample t-test:
#
# �
# =
# (
# �
# ˉ
# �
# −
# �
# ˉ
# �
# )
# (
# �
# �
# 2
# �
# �
# )
# +
# (
# �
# �
# 2
# �
# �
# )
# t=
# (
# n
# A
# ​
#
# s
# A
# 2
# ​
#
# ​
#  )+(
# n
# B
# ​
#
# s
# B
# 2
# ​
#
# ​
#  )
# ​
#
# (
# x
# ˉ
#
# A
# ​
#  −
# x
# ˉ
#
# B
# ​
#  )
# ​
#
#
# where
# �
# ˉ
# �
# x
# ˉ
#
# A
# ​
#   and
# �
# ˉ
# �
# x
# ˉ
#
# B
# ​
#   are the sample means,
# �
# �
# s
# A
# ​
#   and
# �
# �
# s
# B
# ​
#   are the sample standard deviations, and
# �
# �
# n
# A
# ​
#   and
# �
# �
# n
# B
# ​
#   are the sample sizes.
#
# Since sample sizes are not given, we'll proceed assuming sufficiently large sample sizes.
#
# �
# =
# (
# 85
# −
# 82
# )
# (
# 6
# 2
# �
# �
# )
# +
# (
# 5
# 2
# �
# �
# )
# t=
# (
# n
# A
# ​
#
# 6
# 2
#
# ​
#  )+(
# n
# B
# ​
#
# 5
# 2
#
# ​
#  )
# ​
#
# (85−82)
# ​
#
#
# Step 5: Determine the critical t-value
# For a two-tailed test at 0.01 significance level, we need to find the critical t-values for
# �
# /
# 2
# =
# 0.005
# α/2=0.005 in a t-distribution table.
#
# Step 6: Compare the t-statistic and critical t-value
# If the absolute value of the calculated t-statistic is greater than the critical t-value, we reject the null hypothesis.
#
# Step 7: Make a Decision
# Based on the comparison, we either reject or fail to reject the null hypothesis.

# %% [markdown]
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
# of 65. Calculate the 90% confidence interval for the true population mean.

# %% [markdown]
# To calculate the 90% confidence interval for the true population mean, we'll use the formula for a confidence interval for a mean:
#
# Confidence Interval
# =
# �
# ˉ
# ±
# �
# ×
# �
# �
# Confidence Interval=
# x
# ˉ
#  ±Z×
# n
# ​
#
# σ
# ​
#
#
# Where:
#
# �
# ˉ
# x
# ˉ
#   is the sample mean (65 in this case),
# �
# Z is the Z-value corresponding to the desired confidence level,
# �
# σ is the population standard deviation (8 in this case),
# �
# n is the sample size (50 in this case).
# The Z-value for a 90% confidence interval is approximately 1.645 (for a standard normal distribution).
#
# Let's plug the values into the formula and calculate the confidence interval:
#
# Sample Mean (
# �
# ˉ
# )
# =
# 65
# Sample Mean (
# x
# ˉ
#  )=65
# \text{Z-value (for 90% confidence)} = 1.645
# Population Standard Deviation (
# �
# )
# =
# 8
# Population Standard Deviation (σ)=8
# Sample Size (
# �
# )
# =
# 50
# Sample Size (n)=50
#
# Confidence Interval
# =
# 65
# ±
# 1.645
# ×
# 8
# 50
# Confidence Interval=65±1.645×
# 50
# ​
#
# 8
# ​
#
#
# Now, calculate the margin of error:
#
# Margin of Error
# =
# 1.645
# ×
# 8
# 50
# Margin of Error=1.645×
# 50
# ​
#
# 8
# ​
#
#
# Finally, calculate the lower and upper bounds of the confidence interval:
#
# Lower Bound
# =
# �
# ˉ
# −
# Margin of Error
# Lower Bound=
# x
# ˉ
#  −Margin of Error
# Upper Bound
# =
# �
# ˉ
# +
# Margin of Error
# Upper Bound=
# x
# ˉ
#  +Margin of Error
#
# Plug the values into the formulas to calculate the confidence interval.
#
# Let's go ahead and calculate the 90% confidence interval for the true population mean.
#
# Margin of Error
# =
# 1.645
# ×
# 8
# 50
# Margin of Error=1.645×
# 50
# ​
#
# 8
# ​
#
#
# Margin of Error
# ≈
# 1.645
# ×
# 8
# 50
# Margin of Error≈1.645×
# 50
# ​
#
# 8
# ​
#
# Margin of Error
# ≈
# 1.645
# ×
# 8
# 7.07
# Margin of Error≈1.645×
# 7.07
# 8
# ​
#
# Margin of Error
# ≈
# 1.645
# ×
# 1.133
# Margin of Error≈1.645×1.133
# Margin of Error
# ≈
# 1.861745
# Margin of Error≈1.861745
#
# Now, calculate the lower and upper bounds of the confidence interval:
#
# Lower Bound
# =
# �
# ˉ
# −
# Margin of Error
# Lower Bound=
# x
# ˉ
#  −Margin of Error
# Lower Bound
# ≈
# 65
# −
# 1.861745
# Lower Bound≈65−1.861745
# Lower Bound
# ≈
# 63.138255
# Lower Bound≈63.138255
#
# Upper Bound
# =
# �
# ˉ
# +
# Margin of Error
# Upper Bound=
# x
# ˉ
#  +Margin of Error
# Upper Bound
# ≈
# 65
# +
# 1.861745
# Upper Bound≈65+1.861745
# Upper Bound
# ≈
# 66.861745
# Upper Bound≈66.861745
#
# Therefore, the 90% confidence interval for the true population mean is approximately
# (
# 63.138
# ,
# 66.862
# )
# (63.138,66.862). This means we can be 90% confident that the true population mean falls within this range.

# %% [markdown]
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
# reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

# %% [markdown]
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
# reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

# %% [markdown]
# To determine if caffeine has a significant effect on reaction time, we'll conduct a one-sample t-test. Here are the steps involved:
#
# Step 1: Formulate Hypotheses
#
# Null Hypothesis (
# �
# 0
# H
# 0
# ​
#  ): Caffeine has no significant effect on reaction time; the population mean reaction time is the same as the sample mean reaction time.
# �
# 0
# :
# �
# =
# �
# ˉ
# H
# 0
# ​
#  :μ=
# x
# ˉ
#
# Alternative Hypothesis (
# �
# 1
# H
# 1
# ​
#  ): Caffeine has a significant effect on reaction time; the population mean reaction time is different from the sample mean reaction time.
# �
# 1
# :
# �
# ≠
# �
# ˉ
# H
# 1
# ​
#  :μ
# 
# =
# x
# ˉ
#   (two-tailed test)
# Step 2: Choose the Significance Level
# We are given a 90% confidence level, which corresponds to a significance level (
# �
# α) of 0.10. This means we'll reject the null hypothesis if the p-value is less than 0.10.
#
# Step 3: Collect and Summarize Data
# From the information provided:
#
# Sample Mean (
# �
# ˉ
# x
# ˉ
#  ): 0.25 seconds
# Sample Standard Deviation (
# �
# s): 0.05 seconds
# Sample Size (
# �
# n): 30
# Step 4: Conduct the t-test
# We'll use the formula for a one-sample t-test:
#
# �
# =
# (
# �
# ˉ
# −
# �
# )
# �
# �
# t=
# n
# ​
#
# s
# ​
#
# (
# x
# ˉ
#  −μ)
# ​
#
#
# where
# �
# ˉ
# x
# ˉ
#   is the sample mean,
# �
# μ is the population mean under the null hypothesis,
# �
# s is the sample standard deviation, and
# �
# n is the sample size.
#
# Substitute the values into the formula:
#
# �
# =
# (
# 0.25
# −
# �
# )
# 0.05
# 30
# t=
# 30
# ​
#
# 0.05
# ​
#
# (0.25−μ)
# ​
#
#
# Step 5: Determine the critical t-value
# For a two-tailed test at 0.10 significance level, we need to find the critical t-values for
# �
# /
# 2
# =
# 0.05
# α/2=0.05 in a t-distribution table with
# �
# −
# 1
# =
# 29
# n−1=29 degrees of freedom.
#
# Step 6: Compare the t-statistic and critical t-value
# If the absolute value of the calculated t-statistic is greater than the critical t-value, we reject the null hypothesis.
#
# Step 7: Make a Decision
# Based on the comparison, we either reject or fail to reject the null hypothesis.
